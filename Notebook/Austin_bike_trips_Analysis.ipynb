# %%
import pandas as pd

# %%
austin_bike_trips = pd.read_csv('OneDrive/Documents/Python Notebooks Altschool/SECOND SEMESTER/austin_bikeshare_trips.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 austin_bike_trips = pd.read_csv('OneDrive/Documents/Python Notebooks Altschool/SECOND SEMESTER/austin_bikeshare_trips.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
austin_bike_trips.head()
# Out:
#     trip_id       subscriber_type bike_id bike_type               start_time  \
# 0  19309516           Single Trip     647   classic  2019-02-24 09:32:17 UTC
# 1  19309511           Single Trip   12802   classic  2019-02-24 09:31:03 UTC
# 2  19309522           Single Trip    046G   classic  2019-02-24 09:34:16 UTC
# 3  19346245               Local30    263G   classic  2019-03-08 07:37:03 UTC
# 4  19468664  24 Hour Walk Up Pass    2143   classic  2019-03-31 12:16:21 UTC
#
#    start_station_id start_station_name  end_station_id  end_station_name  \
# 0            4051.0   10th & Red River          4051.0  10th & Red River
# 1            4051.0   10th & Red River          4051.0  10th & Red River
# 2            4051.0   10th & Red River          4051.0  10th & Red River
# 3            4051.0   10th & Red River          4051.0  10th & Red River
# 4            4051.0   10th & Red River          4051.0  10th & Red River
#
#    duration_minutes
# 0                12
# 1                 8
# ...

# %%
# A concise summary

austin_bike_trips.info
# Out:
# <bound method DataFrame.info of         trip_id       subscriber_type bike_id bike_type  \
# 0      19309516           Single Trip     647   classic
# 1      19309511           Single Trip   12802   classic
# 2      19309522           Single Trip    046G   classic
# 3      19346245               Local30    263G   classic
# 4      19468664  24 Hour Walk Up Pass    2143   classic
# ...         ...                   ...     ...       ...
# 49995   5302125  24 Hour Walk Up Pass     924   classic
# 49996   5157814  24 Hour Walk Up Pass     861   classic
# 49997   5157804  24 Hour Walk Up Pass     827   classic
# 49998   5088536  24 Hour Walk Up Pass     934   classic
# 49999   5088519  24 Hour Walk Up Pass     116   classic
#
#                     start_time  start_station_id start_station_name  \
# 0      2019-02-24 09:32:17 UTC            4051.0   10th & Red River
# 1      2019-02-24 09:31:03 UTC            4051.0   10th & Red River
# ...

# %%
# Find unique station name

austin_bike_trips['start_station_name'].nunique()
# Out:
# 184

# %%
# Make the  station names lowercases, .str.lower()

austin_bike_trips['start_station_name'].str.lower()
# Out:
# 0        10th & red river
# 1        10th & red river
# 2        10th & red river
# 3        10th & red river
# 4        10th & red river
#                ...
# 49995        rainey/davis
# 49996        rainey/davis
# 49997        rainey/davis
# 49998        rainey/davis
# 49999        rainey/davis
# Name: start_station_name, Length: 50000, dtype: object

# %%
# Take out the extra spaces in the station name columns, .str.strip()

austin_bike_trips['start_station_name'].str.strip()
# Out:
# 0        10th & Red River
# 1        10th & Red River
# 2        10th & Red River
# 3        10th & Red River
# 4        10th & Red River
#                ...
# 49995        Rainey/Davis
# 49996        Rainey/Davis
# 49997        Rainey/Davis
# 49998        Rainey/Davis
# 49999        Rainey/Davis
# Name: start_station_name, Length: 50000, dtype: object

# %%
# Clean up common symbols like &, $, @, /, .str.replace('@', 'at')

austin_bike_trips['start_station_name'].str.replace('@', 'at ').head(50)
# Out:
# 0                  10th & Red River
# 1                  10th & Red River
# 2                  10th & Red River
# 3                  10th & Red River
# 4                  10th & Red River
# 5                  10th & Red River
# 6                  10th & Red River
# 7                  10th & Red River
# 8                  10th & Red River
# 9                  10th & Red River
# 10                 10th & Red River
# 11                 10th & Red River
# 12                 10th & Red River
# 13                 10th & Red River
# 14                 10th & Red River
# 15                 10th & Red River
# 16                 10th & Red River
# 17                 10th & Red River
# 18                   11th & Salina
# 19                   11th & Salina
# 20                   11th & Salina
# 21               11th & San Jacinto
# 22               13th & San Antonio
# 23                 17th & Guadalupe
# 24                 17th & Guadalupe
# 25           21st & Speedway at PCL
# ...
